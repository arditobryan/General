# %% [markdown]
# #Regressors

# %%
#SVR
from sklearn.svm import SVR
clf = SVR(kernel='poly', C=1, gamma='auto', degree=3, epsilon=.1, coef0=1)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
#Ridge Regression
from sklearn.linear_model import Ridge
import numpy as np

clf = Ridge(alpha=1.0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test) #???
print(clf.score(X_test, y_test))

# %%
#ExtraTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import ExtraTreeClassifier
clf = ExtraTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_predict))
print(clf.score(X_test, y_test))

# %% [markdown]
# #Classifiers

# %%
#LogisticRegression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train) #y_train can only be one column
Y_pred = clf.predict(X_test)
acc_log = round(clf.score(X_train, y_train) * 100, 2)
print(acc_log)

# %%
#Perceptron
from sklearn.linear_model import Perceptron
perceptron = Perceptron(max_iter=9)
perceptron.fit(X_train, y_train) #y_train can only be one column
y_pred = perceptron.predict(X_test) #???
acc_perceptron = round(perceptron.score(X_train, y_train) * 100, 2)
print(acc_perceptron)

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
## Instantiate the model with 5 neighbors.
for i in range(1, 20):
  clf = KNeighborsClassifier(n_neighbors=i)  
  ## Fit the model on the training data.
  clf.fit(X_train, y_train)
  ## See how the model performs on the test data.
  print(i, clf.score(X_test, y_test))

  from sklearn.model_selection import cross_val_score
  scores = cross_val_score(clf, X, y, cv=20)
  print(i, scores, scores.mean())

# %%
#RadiusNeighborsClassifier
from sklearn.neighbors import RadiusNeighborsClassifier
## Instantiate the model with 5 neighbors.
knn = RadiusNeighborsClassifier(radius=2.48)
## Fit the model on the training data.
knn.fit(X_train, y_train)
## See how the model performs on the test data.
knn.score(X_test, y_test)

# %%
#NearestCentroid
from sklearn.neighbors import NearestCentroid
import numpy as np
clf = NearestCentroid()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))

# %%
#SMV.SVC
from sklearn.svm import SVC
svc = SVC(gamma='auto')
clf = svc.fit(X_train, y_train)
print(clf.score(X_test, y_test))

# %%
#DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predict)

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_predict))

# %%
#Support Vector Machine
from sklearn import svm
clf = svm.SVC(kernel='linear')

# %%
#SGDClassifier
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=20)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predict)

# %%
v.statistics.cross_validation(10)

# %%
clf.fit(X_train,y_train)
print(clf.score(X_test, y_test))
