# %%
#covid 19 death rate
import matplotlib.pyplot as plt


y = [0.001, .002, .002, .002, .004, .013, .036, .08, .148]
x = [9, 19, 29, 39, 49, 59, 69, 79, 89]

plt.plot(x, y, 'o')

# %%
from scipy.interpolate import interp1d
import numpy as np

f = interp1d(x, y, kind='cubic')
f(10)

plt.plot(f(x))
